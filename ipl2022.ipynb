# %%
# !pip install selenium

# %%
# !pip install bs4

# %%
import pandas as pd
from bs4 import BeautifulSoup as bs
from selenium import webdriver

# %%
from selenium.webdriver.common.by import By

# %%
driver=webdriver.Chrome(executable_path="E:/contact/chromedriver_win32/chromedriver.exe")
# Out:
# C:\Users\nitesh\AppData\Local\Temp\ipykernel_10896\2602234205.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path="E:/contact/chromedriver_win32/chromedriver.exe")

# %%
driver.get("https://www.iplt20.com/stats/2022/")

# %%
driver.title
# Out:
# 'IPLT20.com | Player Stats | Indian Premier League Website'

# %%
l=driver.find_element("link text", "View All")
l.click
# Out:
# <bound method WebElement.click of <selenium.webdriver.remote.webelement.WebElement (session="bc59df62766a74247280492d50eedadd", element="91b2d604-a146-4ab8-8698-a8fbcf1a54fc")>>

# %%
data=driver.page_source
data1=bs(data,"html.parser")

# %%
msn=data1.find('table',class_="np-mostruns_table statsTable ng-scope")

# %%
pos=[]
pl=[]
match=[]
inn=[]
no=[]
runs=[]
hs=[]
avg=[]
bf=[]
sr=[]
hndrd=[]
fif=[]
four=[]
six=[]
rows= msn.find_all('tr')

# %%
matchdetail=[]
for row in rows:
    mn=row.find_all(class_='ng-binding')
    for i in range(0,14):
        for da in range(i,len(mn)):
            if da==0:
                pos.append(mn[da].text)
            elif da==1:
                pl.append(mn[da].text)
            elif da==2:
                match.append(mn[da].text)
            elif da==3:
                inn.append(mn[da].text)
            elif da==4:
                no.append(mn[da].text)
            elif da==5:
                runs.append(mn[da].text)
            elif da==6:
                hs.append(mn[da].text)
            elif da==7:
                avg.append(mn[da].text)
            elif da==8:
                bf.append(mn[da].text)
            elif da==9:
                sr.append(mn[da].text)
            elif da==10:
                hndrd.append(mn[da].text)
            elif da==11:
                fif.append(mn[da].text)
            elif da==12:
                four.append(mn[da].text)
            elif da==13:
                six.append(mn[da].text)
            break;

# %%
df= {'POS':pos,'PLAYER':pl,'MATCH':match,'INNINGS':inn,'NO':no,'RUNS':runs,'HS':hs,'AVG':avg,'BF':bf,'SR':sr,'HUNDRED':hndrd,'FIFTY':fif,'FOUR':four,'Six':six}

# %%
header=['POS','P1','MATCH','INNINGS','NO','RUNS','HS','AVG','BF','SR','HUNDERD','FIFTY','FOUR','SIX']

# %%
new = pd.DataFrame.from_dict(df)

# %%
new
# Out:
#     POS            PLAYER MATCH INNINGS NO RUNS    HS    AVG   BF      SR  \
# 0     1       Jos Buttler    17      17  2  863   116  57.53  579  149.05
# 1     2         K L Rahul    15      15  3  616  103*  51.33  455  135.38
# 2     3   Quinton De Kock    15      15  1  508  140*  36.29  341  148.97
# 3     4     Hardik Pandya    15      15  4  487   87*  44.27  371  131.26
# 4     5      Shubman Gill    16      16  2  483    96  34.50  365  132.32
# ..   ..               ...   ...     ... ..  ...   ...    ...  ...     ...
# 135  16      Shreyas Iyer    14      14  1  401    85  30.85  298  134.56
# 136  17       Tilak Varma    14      14  3  397    61  36.09  303  131.02
# 137  18     Aiden Markram    14      12  4  381   68*  47.63  274  139.05
# 138  19  Devdutt Padikkal    17      17  0  376    54  22.12  306  122.87
# 139  20  Ruturaj  Gaikwad    14      14  0  368    99  26.29  291  126.46
#
#     HUNDRED FIFTY FOUR Six
# 0         4     4   83  45
# ...

# %%
csv_data = new.to_csv("ab.csv")

# %%
print(csv_data)
# Out:
# ,POS,PLAYER,MATCH,INNINGS,NO,RUNS,HS,AVG,BF,SR,HUNDRED,FIFTY,FOUR,Six
# 0,1,Jos Buttler,17,17,2,863,116,57.53,579,149.05,4,4,83,45
# 1,2,K L Rahul,15,15,3,616,103*,51.33,455,135.38,2,4,45,30
# 2,3,Quinton De Kock,15,15,1,508,140*,36.29,341,148.97,1,3,47,23
# 3,4,Hardik Pandya,15,15,4,487,87*,44.27,371,131.26,0,4,49,12
# 4,5,Shubman Gill,16,16,2,483,96,34.50,365,132.32,0,4,51,11
# 5,6,David Miller,16,16,9,481,94*,68.71,337,142.72,0,2,32,23
# 6,7,Faf Du Plessis,16,16,1,468,96,31.20,367,127.52,0,3,49,13
# 7,8,Shikhar Dhawan,14,14,2,460,88*,38.33,375,122.66,0,3,47,12
# 8,9,Sanju Samson,17,17,1,458,55,28.63,312,146.79,0,2,43,26
# 9,10,Deepak Hooda,15,14,0,451,59,32.21,330,136.66,0,4,36,18
# 10,11,Liam Livingstone,14,14,2,437,70,36.42,240,182.08,0,4,29,34
# 11,12,David Warner,12,12,3,432,92*,48.00,287,150.52,0,5,52,15
# 12,13,Abhishek Sharma,14,14,0,426,75,30.43,320,133.12,0,2,47,13
# 13,14,Ishan Kishan,14,14,1,418,81*,32.15,348,120.11,0,3,45,11
# ...

# %%
with open("ipl2022.csv",'w',newline="",encoding='utf-8')as file:
     writer=csv.writer(file)
     writer.writerow(header)
     writer.writerows(matchdetail)

# %%
with open("export.csv", 'w') as csvFile:
        wr = csv.DictWriter(csvFile, fieldnames=col_name)
        wr.writeheader()
        for ele in header
            wr.writerow(ele)
